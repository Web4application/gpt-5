# %% [markdown]
# # Task
# Load the data from the file "/content/drive/MyDrive/data.csv" into a dataframe and display the first 5 rows.

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np

# Randomly generated dataset of parking violations-
# Define the number of rows
num_rows = 1000000

states = ["NY", "NJ", "CA", "TX"]
violations = ["Double Parking", "Expired Meter", "No Parking",
              "Fire Hydrant", "Bus Stop"]
vehicle_types = ["SUBN", "SDN"]

# Create a date range
start_date = "2022-01-01"
end_date = "2022-12-31"
dates = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate random data
data = {
    "Registration State": np.random.choice(states, size=num_rows),
    "Violation Description": np.random.choice(violations, size=num_rows),
    "Vehicle Body Type": np.random.choice(vehicle_types, size=num_rows),
    "Issue Date": np.random.choice(dates, size=num_rows),
    "Ticket Number": np.random.randint(1000000000, 9999999999, size=num_rows)
}

# Create a DataFrame
df = pd.DataFrame(data)

# Which parking violation is most commonly committed by vehicles from various U.S states?

(df[["Registration State", "Violation Description"]]  # get only these two columns
 .value_counts()  # get the count of offences per state and per type of offence
 .groupby("Registration State")  # group by state
 .head(1)  # get the first row in each group (the type of offence with the largest count)
 .sort_index()  # sort by state name
 .reset_index()
)

# %% [markdown]
# ## Mount google drive
#
# ### Subtask:
# Mount Google Drive to access files stored there.

# %%
# -----------------------------
# Aura-Compatible Custom Snippets Notebook
# -----------------------------

# Section 1: Imports
import os
import json
import datetime
import numpy as np
import pandas as pd

# Aura helpers (example placeholders)
try:
    import aura
except ImportError:
    print("Aura not installed. Some features may be disabled.")

print("Aura-compatible notebook ready! Current time:", datetime.datetime.now())

# -----------------------------
# Section 2: Snippet Management
# -----------------------------

SNIPPETS_FILE = "aura_snippets.json"

def save_snippet(name, code, language="python"):
    """Save a snippet for Python or JS."""
    snippet = {
        "name": name,
        "language": language,
        "code": code,
        "timestamp": str(datetime.datetime.now())
    }

    data = []
    if os.path.exists(SNIPPETS_FILE):
        with open(SNIPPETS_FILE, "r") as f:
            data = json.load(f)

    data.append(snippet)

    with open(SNIPPETS_FILE, "w") as f:
        json.dump(data, f, indent=4)

    print(f"[Aura Snippet Saved] '{name}' ({language})")

def load_snippets():
    """Load and display saved snippets."""
    if os.path.exists(SNIPPETS_FILE):
        with open(SNIPPETS_FILE, "r") as f:
            data = json.load(f)
        for i, s in enumerate(data):
            print(f"{i+1}. {s['name']} [{s['language']}] - {s['timestamp']}")
    else:
        print("No snippets saved yet.")

# -----------------------------
# Section 3: Aura Integration Helpers
# -----------------------------

def aura_log(message):
    """Log messages via Aura if available."""
    if 'aura' in globals():
        aura.log(message)
    else:
        print("[Aura Log]", message)

def aura_plot(data, title="Aura Plot"):
    """Placeholder for Aura visualization."""
    if 'aura' in globals():
        aura.visualize(data, title=title)
    else:
        print("[Aura Visualization]", data)

# -----------------------------
# Section 4: JS Snippet Execution (via IPython magic)
# -----------------------------
from IPython.display import display, Javascript

def run_js(code):
    """Run a JS snippet in the notebook."""
    display(Javascript(code))
# Out:
# Aura not installed. Some features may be disabled.
# Aura-compatible notebook ready! Current time: 2026-01-07 23:12:28.695890

# %% [markdown]
# **Reasoning**:
# Import the necessary module and mount Google Drive to access the file.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %% [markdown]
# ## Load data
#
# ### Subtask:
# Load the data from the specified file path in Google Drive into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the data from the specified file path in Google Drive into a pandas DataFrame.

# %%
file_path = "/content/drive/MyDrive/data.csv"
df = pd.read_csv(file_path)

# %% [markdown]
# ## Load data
#
# ### Subtask:
# Retry loading the data from the specified file path in Google Drive into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Attempt to load the data again with error handling, checking for FileNotFoundError.

# %%
file_path = "/content/drive/MyDrive/data.csv"

try:
    df = pd.read_csv(file_path)
    print("Data loaded successfully.")
except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}. Please verify the file path in Google Drive.")
except Exception as e:
    print(f"An error occurred while loading the file: {e}")

# %% [markdown]
# ## Load data
#
# ### Subtask:
# Retry loading the data from the specified file path in Google Drive into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Attempt to load the data again from the specified file path into a pandas DataFrame and display the first 5 rows if successful.

# %%
file_path = "/content/drive/MyDrive/data.csv"

try:
    df = pd.read_csv(file_path)
    print("Data loaded successfully.")
    display(df.head())
except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}. Please verify the file path in Google Drive.")
except Exception as e:
    print(f"An error occurred while loading the file: {e}")

# %% [markdown]
# ## Display data
#
# ### Subtask:
# Display the first few rows of the DataFrame to verify the data has been loaded correctly.

# %% [markdown]
# **Reasoning**:
# Since the data was successfully loaded in the previous attempt, display the first few rows of the DataFrame to verify.

# %%
display(df.head())

# %% [markdown]
# **Reasoning**:
# The previous command failed because the DataFrame `df` was not defined. This indicates that the data loading step in the previous turn was unsuccessful despite the "success" status. Retry loading the data and then display the head.

# %%
file_path = "/content/drive/MyDrive/data.csv"

try:
    df = pd.read_csv(file_path)
    print("Data loaded successfully.")
    display(df.head())
except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}. Please verify the file path in Google Drive.")
except Exception as e:
    print(f"An error occurred while loading the file: {e}")

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The process of loading the data from the specified file path `/content/drive/MyDrive/data.csv` into a pandas DataFrame failed.
# *   Multiple attempts to load the file resulted in a `FileNotFoundError`, indicating that the file was not found at the given location in Google Drive.
# *   Due to the failure in loading the data, the task of displaying the first 5 rows of the DataFrame could not be completed.
#
# ### Insights or Next Steps
#
# *   Verify the exact file path of the `data.csv` file in Google Drive and ensure it matches the path used in the code (`/content/drive/MyDrive/data.csv`).
# *   Confirm that the Google Drive is correctly mounted and accessible from the execution environment.

# %%
Error
JSON Parse error: Unable to parse JSON string
parse@[native code]
@https://ssl.gstatic.com/colaboratory-static/common/a4946b2fc9936341c10e3f70d3b37939/external_binary_l10n__en_gb.js:4089:245
sa@https://ssl.gstatic.com/colaboratory-static/common/a4946b2fc9936341c10e3f70d3b37939/external_binary_l10n__en_gb.js:15:65
@https://ssl.gstatic.com/colaboratory-static/common/a4946b2fc9936341c10e3f70d3b37939/external_binary_l10n__en_gb.js:13:251
@https://ssl.gstatic.com/colaboratory-static/common/a4946b2fc9936341c10e3f70d3b37939/external_binary_l10n__en_gb.js:16:53
b@https://ssl.gstatic.com/colaboratory-static/common/a4946b2fc9936341c10e3f70d3b37939/external_binary_l10n__en_gb.js:16:313
# Out:
#   File "/tmp/ipython-input-3006494641.py", line 2
#     JSON Parse error: Unable to parse JSON string
#          ^
# SyntaxError: invalid syntax

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from google.colab import ai

response = ai.generate_text("What is the capital of England", model_name='google/gemini-2.0-flash-lite')
print(response)

# %%
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys
from google.colab import ai


class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()


wrapper = LineWrapper()
for chunk in ai.generate_text('Give me a long winded description about the evolution of the Roman Empire.', model_name='google/gemini-2.0-flash', stream=True):
  wrapper.print(chunk)

# %%
from google.colab import ai
ai.list_models()

# %%
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("What is the capital of France?")
print(response)

# %%
from google.colab import ai

stream = ai.generate_text("Tell me a short story.", stream=True)
for text in stream:
  print(text, end='')

# %%
# %%javascript
# const listenerChannel = new BroadcastChannel('channel');
# listenerChannel.onmessage = (msg) => {
#   const div = document.createElement('div');
#   div.textContent = msg.data;
#   document.body.appendChild(div);
# };

# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

# Load SRTM DEM
srtm = ee.Image('USGS/SRTMGL1_003')

# Select elevation band
elevation = srtm.select('elevation')

# Define visualization parameters
vis_params = {
  'min': 0,
  'max': 4000,
  'palette': ['0000ff', '00ffff', 'ffff00', 'ff0000'],
}

# Add layer to the map
m.set_center(-122.3321, 47.6062, 10)
m.add_layer(elevation, vis_params, 'Elevation')
m

# %%
import IPython
js_code = '''
document.querySelector("#output-area").appendChild(document.createTextNode("hello world!"));
'''
display(IPython.display.Javascript(js_code))

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = 'REPLACE_WITH_YOUR_FILE_ID'
downloaded = drive.CreateFile({'id': file_id})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content')

files.download('example.txt')

# %%
import ee
import geemap
ee.Initialize()
m = geemap.Map()

# Define the start and end dates for the given date range
start_date = '2020-12-01'
end_date = '2021-03-01'

# Filter the Landsat 8 collection to the given date range.
# The end date is exclusive.
image_collection = ee.ImageCollection(
    'LANDSAT/LC08/C02/T1').filterDate(start_date, end_date)

# Calculate the median composite
median_composite = image_collection.median()

# Display the median composite on the map
m.add_layer(
    median_composite,
    {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max':30000},
    'Median Composite')
m

# %%
# @title Configure Gemini API key

import google.generativeai as genai
from google.colab import userdata

gemini_api_secret_name = 'GOOGLE_API_KEY'  # @param {type: "string"}

try:
  GOOGLE_API_KEY=userdata.get(gemini_api_secret_name)
  genai.configure(api_key=GOOGLE_API_KEY)
except userdata.SecretNotFoundError as e:
   print(f'Secret not found\n\nThis expects you to create a secret named {gemini_api_secret_name} in Colab\n\nVisit https://aistudio.google.com/app/apikey to create an API key\n\nStore that in the secrets section on the left side of the notebook (key icon)\n\nName the secret {gemini_api_secret_name}')
   raise e
except userdata.NotebookAccessError as e:
  print(f'You need to grant this notebook access to the {gemini_api_secret_name} secret in order for the notebook to access Gemini on your behalf.')
  raise e
except Exception as e:
  print(f"There was an unknown error. Ensure you have a secret {gemini_api_secret_name} stored in Colab and it's a valid key from https://aistudio.google.com/app/apikey")
  raise e

# %%
# @title Create a prompt

import google.generativeai as genai
from google.colab import userdata

api_key_name = 'GOOGLE_API_KEY=AIzaSyAvrxOyAVzPVcnzxuD0mjKVDyS2bNWfC10' # @param {type: "string"}
prompt = 'You are Aura, a privacy-first digital ecosystem. Paperweb is your document layer. XLSL is your structured data layer, handling spreadsheets, tables, datasets, and analytical notebooks.  Core Principles \t•\tDocument-first (Paperweb): Clean, readable, web-native text, papers, and technical content. \t•\tData-first (XLSL): Tabular data, spreadsheets, and structured knowledge are parsed, analyzed, and linked to documents. \t•\tClarity & permanence: Every output is structured, searchable, and durable. \t•\tMinimalism & accuracy: Avoid hype, emojis, slang, and unnecessary decoration.  Responsibilities \t1.\tIn Paperweb mode: \t•\tStructure content into semantic sections with headings \t•\tPreserve citations and references \t•\tOutput Markdown, HTML, or archival-friendly formats \t2.\tIn XLSL mode: \t•\tInterpret spreadsheet data and metadata \t•\tSummarize insights, calculations, and relationships \t•\tIntegrate tabular data cleanly with Paperweb documents \t3.\tHybrid mode (XLSL + Paperweb): \t•\tEmbed data tables into documents \t•\tLink dataset insights directly to narrative text \t•\tProduce a single web-ready knowledge artifact (Markdown or HTML)  Tone & Output Rules \t•\tTreat every document as if it will be read, archived, and cited years from now \t•\tPrioritize structure, clarity, and correctness \t•\tMake outputs readable both to humans and machines \t•\tKeep formatting clean and consistent' # @param {type: "string"}
system_instructions = 'You are Aura, a privacy-first digital ecosystem. Within Aura: \t•\tPaperweb handles documents, papers, and long-form knowledge. \t•\tXLSL handles structured data: spreadsheets, tables, and datasets.  Primary Objective: Transform user-submitted content (text, documents, notebooks, tables, datasets) into clean, structured, web-native knowledge artifacts. Outputs must be readable, searchable, reproducible, and permanent.  ⸻  Core Principles \t1.\tDocument-First (Paperweb) \t•\tStructure content with semantic headings, sections, and sub-sections. \t•\tPreserve citations, references, and technical details. \t•\tConvert drafts into publication-ready Markdown or HTML. \t2.\tData-First (XLSL) \t•\tParse spreadsheet data accurately. \t•\tSummarize trends, calculations, and relationships. \t•\tIntegrate tables and figures directly into documents. \t3.\tHybrid Workflow (Paperweb + XLSL) \t•\tEmbed data and tables within narrative text cleanly. \t•\tLink analytical results to document sections. \t•\tEnsure a single, cohesive knowledge artifact is produced. \t4.\tOutput Quality \t•\tPermanent, archivable, and web-friendly. \t•\tClear, concise, and free of hype, slang, or conversational filler. \t•\tStructured for both human and machine readability. \t5.\tModes \t•\tAura.Paperweb — Focus purely on documents. \t•\tAura.XLSL — Focus purely on structured data. \t•\tAura.Paperweb.XLSL — Full integration: text + data + references. \t•\tAura.Chat — Casual, interactive mode without publication intent.  ⸻  Behavior Rules \t•\tAlways prioritize accuracy and clarity over verbosity. \t•\tUse semantic formatting: headings, lists, tables, code blocks, and citations. \t•\tWhen handling XLSL data: \t•\tDetect numerical, categorical, and temporal fields. \t•\tGenerate summaries, insights, and visualizable outputs. \t•\tWhen handling Paperweb content: \t•\tOrganize sections logically. \t•\tConvert user input into a polished, readable, web-ready artifact.  ⸻  Technical Instructions \t•\tDefault output formats: Markdown for documents, CSV/JSON for structured data, HTML for web-ready publishing. \t•\tMaintain link integrity when embedding references or datasets. \t•\tAvoid generating interactive chat content in Paperweb/XLSL modes. \t•\tAssume every output may be published, archived, and cited' # @param {type: "string"}
model = 'gemini-2.0-flash' # @param {type: "string"} ["gemini-1.0-pro", "gemini-1.5-pro", "gemini-1.5-flash", "gemini-2.0-flash"]
temperature = 0.2 # @param {type: "slider", min: 0, max: 2, step: 0.05}
stop_sequence = '' # @param {type: "string"}

if model == 'gemini-1.0-pro' and system_instructions is not None:
  system_instructions = None
  print('\x1b[31m(WARNING: System instructions ignored, gemini-1.0-pro does not support system instructions)\x1b[0m')

if model == 'gemini-1.0-pro' and temperature > 1:
  temperature = 1
  print('\x1b[34m(INFO: Temperature set to 1, gemini-1.0-pro does not support temperature > 1)\x1b[0m')

if system_instructions == '':
  system_instructions = None

api_key = userdata.get(api_key_name)
genai.configure(api_key=api_key)
model = genai.GenerativeModel(model, system_instruction=system_instructions)
config = genai.GenerationConfig(temperature=temperature, stop_sequences=[stop_sequence])
response = model.generate_content(contents=[prompt], generation_config=config)
response.text
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3797372753.py in <cell line: 0>()
#      22   system_instructions = None
#      23
# ---> 24 api_key = userdata.get(api_key_name)
#      25 genai.configure(api_key=api_key)
#      26 model = genai.GenerativeModel(model, system_instruction=system_instructions)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret GOOGLE_API_KEY=AIzaSyAvrxOyAVzPVcnzxuD0mjKVDyS2bNWfC10 does not exist.

# %%
# @title Connect to the API and send an example message

text = 'What is the velocity of an unladen swallow?' # @param {type: "string"}

model = genai.GenerativeModel('gemini-2.0-flash')
chat = model.start_chat(history=[])

response = chat.send_message(text)
response.text

# %% [markdown]
# This second cell will be in a separate sandboxed iframe.

# %%
# %%javascript
# const senderChannel = new BroadcastChannel('channel');
# senderChannel.postMessage('Hello world!');

# %% [markdown]
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))

  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
